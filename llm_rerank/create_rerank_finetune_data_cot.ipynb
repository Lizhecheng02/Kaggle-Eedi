# %%
import pandas as pd

# %%
train_path = '../datas/train.csv'
test_path = '../datas/test.csv'
sample_path = '../datas/sample_submission.csv'
mapping_path = '../datas/misconception_mapping.csv'

m_map = pd.read_csv(mapping_path)
mis_concepts = m_map['MisconceptionName'].tolist()
m_map.head()
# Out:
#    MisconceptionId                                  MisconceptionName
# 0                0  Does not know that angles in a triangle sum to...
# 1                1  Uses dividing fractions method for multiplying...
# 2                2      Believes there are 100 degrees in a full turn
# 3                3  Thinks a quadratic without a non variable term...
# 4                4  Believes addition of terms and powers of terms...

# %%
train_cot_path = './datas/cot/train_cot_data.parquet'
dev_cot_path = './datas/cot/model_ge n_cot_dev.parquet'

# %%
train_cot = pd.read_parquet(train_cot_path)
train_cot.head()
# Out:
#    QuestionId  ConstructId                                      ConstructName  \
# 0         300          414  Order fractions whose denominators are multipl...
# 1         300          414  Order fractions whose denominators are multipl...
# 2         300          414  Order fractions whose denominators are multipl...
# 3         301         1743    Find missing angles using angles around a point
# 4         301         1743    Find missing angles using angles around a point
#
#    SubjectId                                        SubjectName  \
# 0        102  Averages (mean, median, mode) from a List of Data
# 1        102  Averages (mean, median, mode) from a List of Data
# 2        102  Averages (mean, median, mode) from a List of Data
# 3        181  Basic Angle Facts (straight line, opposite, ar...
# 4        181  Basic Angle Facts (straight line, opposite, ar...
#
#                                         QuestionText       CorrectAnswer  \
# 0  \begin{tabular}{llllll}\n\( \frac{2}{10} \) & ...  \( \frac{9}{20} \)
# 1  \begin{tabular}{llllll}\n\( \frac{2}{10} \) & ...  \( \frac{9}{20} \)
# 2  \begin{tabular}{llllll}\n\( \frac{2}{10} \) & ...  \( \frac{9}{20} \)
# 3  What is the size of angle \( x \) ? ![Angles a...    \( 50^{\circ} \)
# 4  What is the size of angle \( x \) ? ![Angles a...    \( 50^{\circ} \)
#
#              AnswerText  IsCorrect  MisconceptionId  \
# 0    \( \frac{2}{10} \)          0            758.0
# 1  \( \frac{19}{100} \)          0            197.0
# 2            \( 0.21 \)          0            758.0
# 3     \( 310^{\circ} \)          0            415.0
# 4      \( 90^{\circ} \)          0           2334.0
#
#                                    MisconceptionName  \
# 0  Believes an outlier is a value that does not f...
# 1  Believes an outlier is the value in a data set...
# 2  Believes an outlier is a value that does not f...
# 3  Incorrectly identifies angles as vertically op...
# 4  Does not know that angles around a point sum t...
#
#                                            cot_input  \
# 0  You are an excellent teacher with a keen abili...
# 1  You are an excellent teacher with a keen abili...
# 2  You are an excellent teacher with a keen abili...
# 3  You are an excellent teacher with a keen abili...
# 4  You are an excellent teacher with a keen abili...
#
#                                        cot_inference  \
# 0  The student likely approached the question by ...
# 1  The student's incorrect choice of \( \frac{19}...
# 2  The student's answer of \(0.21\) instead of th...
# 3  The student answered \( 310^{\circ} \) for ang...
# 4  The student likely approached the problem by r...
#
#                                                query
# 0  #Construct Name: Order fractions whose denomin...
# 1  #Construct Name: Order fractions whose denomin...
# 2  #Construct Name: Order fractions whose denomin...
# 3  #Construct Name: Find missing angles using ang...
# 4  #Construct Name: Find missing angles using ang...

# %%
train_cot = train_cot.rename(columns={'AnswerText': "InCorrectAnswerText"})
train_cot.head()
# Out:
#    QuestionId  ConstructId                                      ConstructName  \
# 0         300          414  Order fractions whose denominators are multipl...
# 1         300          414  Order fractions whose denominators are multipl...
# 2         300          414  Order fractions whose denominators are multipl...
# 3         301         1743    Find missing angles using angles around a point
# 4         301         1743    Find missing angles using angles around a point
#
#    SubjectId                                        SubjectName  \
# 0        102  Averages (mean, median, mode) from a List of Data
# 1        102  Averages (mean, median, mode) from a List of Data
# 2        102  Averages (mean, median, mode) from a List of Data
# 3        181  Basic Angle Facts (straight line, opposite, ar...
# 4        181  Basic Angle Facts (straight line, opposite, ar...
#
#                                         QuestionText       CorrectAnswer  \
# 0  \begin{tabular}{llllll}\n\( \frac{2}{10} \) & ...  \( \frac{9}{20} \)
# 1  \begin{tabular}{llllll}\n\( \frac{2}{10} \) & ...  \( \frac{9}{20} \)
# 2  \begin{tabular}{llllll}\n\( \frac{2}{10} \) & ...  \( \frac{9}{20} \)
# 3  What is the size of angle \( x \) ? ![Angles a...    \( 50^{\circ} \)
# 4  What is the size of angle \( x \) ? ![Angles a...    \( 50^{\circ} \)
#
#     InCorrectAnswerText  IsCorrect  MisconceptionId  \
# 0    \( \frac{2}{10} \)          0            758.0
# 1  \( \frac{19}{100} \)          0            197.0
# 2            \( 0.21 \)          0            758.0
# 3     \( 310^{\circ} \)          0            415.0
# 4      \( 90^{\circ} \)          0           2334.0
#
#                                    MisconceptionName  \
# 0  Believes an outlier is a value that does not f...
# 1  Believes an outlier is the value in a data set...
# 2  Believes an outlier is a value that does not f...
# 3  Incorrectly identifies angles as vertically op...
# 4  Does not know that angles around a point sum t...
#
#                                            cot_input  \
# 0  You are an excellent teacher with a keen abili...
# 1  You are an excellent teacher with a keen abili...
# 2  You are an excellent teacher with a keen abili...
# 3  You are an excellent teacher with a keen abili...
# 4  You are an excellent teacher with a keen abili...
#
#                                        cot_inference  \
# 0  The student likely approached the question by ...
# 1  The student's incorrect choice of \( \frac{19}...
# 2  The student's answer of \(0.21\) instead of th...
# 3  The student answered \( 310^{\circ} \) for ang...
# 4  The student likely approached the problem by r...
#
#                                                query
# 0  #Construct Name: Order fractions whose denomin...
# 1  #Construct Name: Order fractions whose denomin...
# 2  #Construct Name: Order fractions whose denomin...
# 3  #Construct Name: Find missing angles using ang...
# 4  #Construct Name: Find missing angles using ang...

# %%
train_df = pd.read_json('../datas/data/train_data.json')
train_sub_df = pd.read_csv("./datas/nvembed_v1/nvembed_no_llm_train.csv")
train_df = train_df.merge(train_sub_df, on='QuestionId_Answer', how='left')
train_df = train_df.merge(train_cot[['QuestionId', 'InCorrectAnswerText', 'cot_inference']], on=['QuestionId', 'InCorrectAnswerText'], how='left')
train_df.head()
# Out:
#   QuestionId_Answer  QuestionId  ConstructId  \
# 0               0_D           0          856
# 1               1_A           1         1612
# 2               1_B           1         1612
# 3               1_C           1         1612
# 4               2_A           2         2774
#
#                                        ConstructName  SubjectId  \
# 0  Use the order of operations to carry out calcu...         33
# 1  Simplify an algebraic fraction by factorising ...       1077
# 2  Simplify an algebraic fraction by factorising ...       1077
# 3  Simplify an algebraic fraction by factorising ...       1077
# 4            Calculate the range from a list of data        339
#
#                                          SubjectName  \
# 0                                             BIDMAS
# 1                    Simplifying Algebraic Fractions
# 2                    Simplifying Algebraic Fractions
# 3                    Simplifying Algebraic Fractions
# 4  Range and Interquartile Range from a List of Data
#
#                                         QuestionText CorrectAnswer  \
# 0  \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...             A
# 1  Simplify the following, if possible: \( \frac{...             D
# 2  Simplify the following, if possible: \( \frac{...             D
# 3  Simplify the following, if possible: \( \frac{...             D
# 4  Tom and Katie are discussing the \( 5 \) plant...             B
#
#        CorrectAnswerText InCorrectAnswer     InCorrectAnswerText  \
# 0  \( 3 \times(2+4)-5 \)               D  Does not need brackets
# 1      Does not simplify               A               \( m+1 \)
# 2      Does not simplify               B               \( m+2 \)
# 3      Does not simplify               C               \( m-1 \)
# 4            Only\nKatie               A               Only\nTom
#
#    MisconceptionId_x                                  MisconceptionName  \
# 0               1672  Confuses the order of operations, believes add...
# 1               2142  Does not know that to factorise a quadratic ex...
# 2                143  Thinks that when you cancel identical terms fr...
# 3               2142  Does not know that to factorise a quadratic ex...
# 4               1287  Believes if you changed all values by the same...
#
#                                    MisconceptionId_y  \
# 0  1005 1507 2532 315 706 1672 1941 1345 2306 139...
# 1  1593 2398 1755 167 3 891 59 363 265 1766 2549 ...
# 2  1593 2398 1755 167 3 891 1766 363 59 265 2549 ...
# 3  1593 2398 1755 891 59 167 3 1766 363 2549 1540...
# 4  1073 1287 2439 397 2471 1677 1059 691 1349 231...
#
#                                        cot_inference
# 0  The student's response indicates a fundamental...
# 1  The student likely approached the problem with...
# 2  The student's response of \( m + 2 \) suggests...
# 3  The student's answer of \( m-1 \) indicates a ...
# 4  The student’s response indicates a misundersta...

# %%
def get_random_neg(label, preds, k=5):
    preds_list = preds.split()
    label = int(label)
    
    samples = []
    for neg in preds_list:
        neg = int(neg)
        if neg == label:continue
        samples.append(mis_concepts[neg])
    return samples[0:k]

# %%
total_examples = []
# IncorrectReason
for i in range(len(train_df)):
    tmp = {}
    tmp['query'] = f"ConstructName:{train_df.loc[i, 'ConstructName']}\nQuestionText:{train_df.loc[i, 'QuestionText']}\nCorrectAnswerText:{train_df.loc[i, 'CorrectAnswerText']}\nInCorrectAnswerText:{train_df.loc[i, 'InCorrectAnswerText']}\nIncorrectReason:{train_df.loc[i, 'cot_inference']}"
    tmp['pos'] = [train_df.loc[i, 'MisconceptionName']]
    tmp['neg'] = get_random_neg(int(train_df.loc[i, "MisconceptionId_x"]), train_df.loc[i, "MisconceptionId_y"], 100)
    tmp['prompt'] = "Given a mathematical question that includes both a correct and an incorrect answer, along with a specific misconception, determine whether this misconception can explain why the student selected the incorrect answer. Please provide a prediction of either 'Yes' or 'No'."
    total_examples.append(tmp)
s = set()
for k in total_examples:
    s |= set(k['neg'])

# assert len(s) == len(mis_concepts)

# %%
import json
filename = './datas/nvembed_v1/nvembed_v1_no_llm_recall_top_15_for_rank.jsonl'
with open(filename, 'w', encoding='utf-8') as f:
    for entry in total_examples:
        json.dump(entry, f, ensure_ascii=False)
        f.write('\n')

# %%
total_examples[0]
# Out:
# {'query': 'ConstructName:Use the order of operations to carry out calculations involving powers\nQuestionText:\\[\n3 \\times 2+4-5\n\\]\nWhere do the brackets need to go to make the answer equal \\( 13 \\) ?\nCorrectAnswerText:\\( 3 \\times(2+4)-5 \\)\nInCorrectAnswerText:Does not need brackets',
#  'pos': ['Confuses the order of operations, believes addition comes before multiplication '],
#  'neg': ['Carries out operations from left to right regardless of priority order, unless brackets are used',
#   'Carries out operations from left to right regardless of priority order',
#   'Believes order of operations does not affect the answer to a calculation',
#   'Has not realised that the answer may be changed by the insertion of brackets',
#   'Carries out operations from right to left regardless of priority order',
#   'Confuses the order of operations, believes subtraction comes before multiplication ',
#   'Inserts brackets but not changed order of operation',
#   'Applies BIDMAS in strict order (does not realize addition and subtraction, and multiplication and division, are of equal priority)',
#   'Does not include brackets when required',
#   'May have made a calculation error using the order of operations',
#   'Misunderstands order of operations in algebraic expressions',
#   'Believes that the order of a worded calculation should be changed to follow BIDMAS ',
#   'Answers order of operations questions with brackets as if the brackets are not there',
#   'Thinks positive or negative sign affects the term before it',
#   'Does not interpret the correct order of operations from a worded problem',
#   'Has removed brackets but not performed the operation',
#   'Performs addition ahead of multiplication',
#   'Performs addition ahead of subtraction',
#   'Does not understand the effect of consecutive operations',
#   'Confuses the order of operations, believes addition comes before division',
#   'Has completed only one of the two operations.',
#   'Does not know the distributive property',
#   'Performs addition ahead of any other operation',
#   'Does not include brackets when attempting to multiply an expression',
#   'Changes the given operation when substituting',
#   'Does not recognise the distributive property',
#   'Believes addition comes before indices, in orders of operation',
#   'Believes adding two negatives gives a positive answer',
#   'Performs subtraction right to left if priority order means doing a calculation to the right first',
#   'Ignores the negative sign',
#   'Ignores the negative signs when adding positive and negative numbers',
#   'When subtracting a negative number from a positive number, uses a method which assumes one of the negative signs can be ignored ',
#   'Performs subtraction in wrong order',
#   'Believes multiplying two negatives gives a negative answer',
#   "Doesn't recognise commutativity of addition with negative numbers",
#   'Believes the smaller number is always subtracted from the larger, regardless of the order of the calculation',
#   'Subtracts from left to right, ignoring the word ‘from’',
#   'Believes subtraction is commutative ',
#   'Performs addition ahead of division',
#   'When adding negatives believes that they can just add their absolute values and add a negative sign to the answer',
#   'Done a different calculation to the one given',
#   'Thinks signs are interchangeable when adding or subtracting positive and negative numbers',
#   'Believes multiplying a positive by a negative gives a positive answer',
#   'Does not reverse the order of operations when solving an equation',
#   'Does not correctly apply the distributive property of multiplication',
#   'Ignores negative sign when expanding bracket',
#   'Does not understand that the negative outside the bracket means answer will be negative',
#   'Only multiplies the first term in the expansion of a bracket',
#   'Does not realise addition is commutative',
#   'Does not realize we can omit the multiplication symbol in algebraic expressions',
#   'Multiplies before applying a power ',
#   'Thinks that a number in front of a bracket means divide',
#   'Adds instead of subtracts',
#   'Thinks a divide and a negative sign next to each other makes a plus',
#   'When subtracting a negative number, adds the absolute values and then writes the answer with a negative sign',
#   'Only multiplies second term in the expansion of a bracket',
#   'Does not understand that the numerator and denominator of fractions represent groupings and have the same order of priority as brackets',
#   'Subtracts instead of adds',
#   'Believes multiplication is not commutative',
#   'Thinks a divide and a negative sign next to each other makes a minus',
#   'Believes that adding a negative will increase the value of the original number',
#   'Does not correctly apply the commutative property of multiplication',
#   'Believes you can add or subtract from inside brackets without expanding when solving an equation',
#   'Believes division is carried out before a power',
#   'Does not realise that two letters together are multiplying',
#   'Thinks you apply one inverse operation to one term and the other inverse operation to the other term',
#   'Believes they must expand brackets before solving an equation',
#   'Thinks two variables next to each other represent addition',
#   'Believes the negative of a positive squared (where there are no brackets) gives a positive answer',
#   "Does not realise that subtracting a negative is the same as adding it's additive inverse",
#   'Believes multiplying two positives gives a negative answer',
#   'When multiplying with negative numbers, assumes any negative sign can be ignored',
#   'When subtracting past zero, adds the absolute values and then writes the answer with a negative sign',
#   'Believes you can subtract from inside brackets without expanding when solving an equation',
#   "When there's a negative sign in the question, thinks the answer must be negative",
#   'Does not understand the concept of inverse operations in algebra',
#   'Does not interpret the correct order of operations in a fraction when there is an addition on the numerator',
#   'Uses addition instead of the associative property of multiplication',
#   'Believes a subtraction cannot be partitioned into separate subtractions',
#   'Subtracts instead of multiplies',
#   'Thinks that we can remove a division symbol and just write the variables next to each other',
#   'Rounds too early in calculation ',
#   'When expanding brackets, multiplies out the first term correctly but adds together the number outside the bracket with the second term inside the bracket.',
#   'When multiplying out 2 or more brackets, does not multiply all the combinations of terms',
#   'Adds instead of multiplies',
#   'Multiplies all terms together when simplifying an expression',
#   'Multiplies rather than adds ',
#   'Has made an order of operations mistake when writing a formula from a given situation',
#   'Thinks subtracting a negative makes your answer smaller',
#   'Does not realise that multiplication can be broken down into factors',
#   'Confusion over whether multiplication or division is the correct way to solve the problem.',
#   'Believes the integer can be written before or after the surd eg. 3√2 = √2 3',
#   "Hasn't lined up the place value columns when writing out the calculation",
#   'Thinks multiplication and addition are the same',
#   'Believes that adding a positive to a negative makes your answer more negative',
#   'Adds instead of multiplying when expanding bracket',
#   'Does not understand the meaning of the word commutative ',
#   'When subtracting from a negative thinks the answer must be positive',
#   'When multiplying just writes the numbers next to each other',
#   'When subtracting a negative thinks the answer must be negative '],
#  'prompt': "Given a mathematical question that includes both a correct and an incorrect answer, along with a specific misconception, determine whether this misconception can explain why the student selected the incorrect answer. Please provide a prediction of either 'Yes' or 'No'."}

# %%
len(mis_concepts)
# Out:
# 2587

# %%
len(s)
# Out:
# 2562
